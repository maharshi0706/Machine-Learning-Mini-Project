# %%
import pandas as pd
import numpy as np
import seaborn as sns
import glob
import os

df = pd.concat(
    map(pd.read_csv, glob.glob(os.path.join("../Datasets/","*.csv" ))), ignore_index= True)
df
# Out:
#      Div        Date        HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0     E0    13/08/16         Burnley      Swansea     0     1   A     0     0
# 1     E0    13/08/16  Crystal Palace    West Brom     0     1   A     0     0
# 2     E0    13/08/16         Everton    Tottenham     1     1   D     1     0
# 3     E0    13/08/16            Hull    Leicester     2     1   H     1     0
# 4     E0    13/08/16        Man City   Sunderland     2     1   H     1     0
# ...   ..         ...             ...          ...   ...   ...  ..   ...   ...
# 2655  E0  28/05/2023         Everton  Bournemouth     1     0   H     0     0
# 2656  E0  28/05/2023           Leeds    Tottenham     1     4   A     0     1
# 2657  E0  28/05/2023       Leicester     West Ham     2     1   H     1     0
# 2658  E0  28/05/2023      Man United       Fulham     2     1   H     1     1
# 2659  E0  28/05/2023     Southampton    Liverpool     4     4   D     2     2
#
#      HTR  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0      D  ...      NaN   NaN       NaN       NaN    NaN    NaN      NaN
# 1      D  ...      NaN   NaN       NaN       NaN    NaN    NaN      NaN
# 2      H  ...      NaN   NaN       NaN       NaN    NaN    NaN      NaN
# 3      H  ...      NaN   NaN       NaN       NaN    NaN    NaN      NaN
# 4      H  ...      NaN   NaN       NaN       NaN    NaN    NaN      NaN
# ...   ..  ...      ...   ...       ...       ...    ...    ...      ...
# 2655   D  ...     2.14 -1.00      2.02      1.77   2.10   1.81     2.17
# 2656   A  ...     2.50  0.25      1.84      2.06   1.83   2.10     1.90
# 2657   H  ...     2.51 -0.25      1.75      2.05   1.85   2.06     1.90
# 2658   D  ...     2.95 -1.25      1.98      1.92   1.98   1.93     2.07
# 2659   D  ...     3.22  1.25      1.82      2.08   1.85   2.07     1.96
#
#       MaxCAHA  AvgCAHH  AvgCAHA
# 0         NaN      NaN      NaN
# 1         NaN      NaN      NaN
# 2         NaN      NaN      NaN
# 3         NaN      NaN      NaN
# 4         NaN      NaN      NaN
# ...       ...      ...      ...
# 2655     1.92     2.03     1.83
# 2656     2.14     1.81     2.06
# 2657     2.16     1.82     2.04
# 2658     1.98     1.97     1.89
# 2659     2.12     1.88     1.98
#
# [2660 rows x 127 columns]

# %%
df.rename(columns={'FTHG':'FTHomeGoals','FTAG':'FTAwayGoals','FTR':'FTResult','HTR':'HTResult','HTHG':'HTHomeGoals','HTAG':'HTAwayGoals'
                        ,'HS':'HomeShots','AS':'AwayShots','HST':'HomeShotsTarget','HHW':'HomeWoodwork','AHW':'AwayWoodwork',
                        'HC':'HomeCorners','AC':'AwayCorners','HF':'HomeFouls','AF':'AwayFouls','HFKC':'AwayFreekicks'
                        ,'AFKC':'HomeFreekicks','HO':'HomeOffsides','AO':'AwayOffsides','HY':'HomeYellow','AY':'AwayYellow',
                        'HR':'HomeRed','AR':'AwayRed','HBP':'HomeBookingPoints','ABP':'AwayBookingPoints'},inplace=True)

# %%
df.drop(df.iloc[:,24:126], inplace=True, axis=1)
# df.drop(['B365H'])
df
# Out:
#      Div        Date        HomeTeam     AwayTeam  FTHomeGoals  FTAwayGoals  \
# 0     E0    13/08/16         Burnley      Swansea            0            1
# 1     E0    13/08/16  Crystal Palace    West Brom            0            1
# 2     E0    13/08/16         Everton    Tottenham            1            1
# 3     E0    13/08/16            Hull    Leicester            2            1
# 4     E0    13/08/16        Man City   Sunderland            2            1
# ...   ..         ...             ...          ...          ...          ...
# 2655  E0  28/05/2023         Everton  Bournemouth            1            0
# 2656  E0  28/05/2023           Leeds    Tottenham            1            4
# 2657  E0  28/05/2023       Leicester     West Ham            2            1
# 2658  E0  28/05/2023      Man United       Fulham            2            1
# 2659  E0  28/05/2023     Southampton    Liverpool            4            4
#
#      FTResult  HTHomeGoals  HTAwayGoals HTResult  ... HomeFouls  AwayFouls  \
# 0           A            0            0        D  ...        10         14
# 1           A            0            0        D  ...        12         15
# 2           D            1            0        H  ...        10         14
# 3           H            1            0        H  ...         8         17
# 4           H            1            0        H  ...        11         14
# ...       ...          ...          ...      ...  ...       ...        ...
# 2655        H            0            0        D  ...        11         12
# 2656        A            0            1        A  ...         7          5
# 2657        H            1            0        H  ...         8         10
# 2658        H            1            1        D  ...        14         10
# 2659        D            2            2        D  ...         4         10
#
#       HomeCorners  AwayCorners  HomeYellow  AwayYellow  HomeRed  AwayRed  \
# 0               7            4           3           2        0        0
# 1               3            6           2           2        0        0
# 2               5            6           0           0        0        0
# 3               5            3           2           2        0        0
# 4               9            6           1           2        0        0
# ...           ...          ...         ...         ...      ...      ...
# 2655            9            3           1           3        0        0
# 2656           12            3           3           0        0        0
# 2657            3            5           1           1        0        0
# 2658            5            4           1           2        0        0
# 2659            2            9           0           2        0        0
#
#       B365H  AvgCAHA
# 0      2.40      NaN
# 1      2.00      NaN
# 2      3.20      NaN
# 3      4.50      NaN
# 4      1.25      NaN
# ...     ...      ...
# 2655   1.50     1.83
# 2656   2.75     2.06
# 2657   1.91     2.04
# 2658   1.50     1.89
# 2659   6.50     1.98
#
# [2660 rows x 25 columns]

# %%
numerical = df.select_dtypes(include=['int', 'float']).columns
categorical_cols = df.select_dtypes(include=['object']).columns

# Impute missing values for numerical features with mean
for col in numerical:
    mean_value = df[col].mean()
    df[col].fillna(mean_value, inplace=True)

# Impute missing values for categorical features with mode
for col in categorical_cols:
    mode_value = df[col].mode().iloc[0]  # Get the most frequent category
    df[col].fillna(mode_value, inplace=True)

df
# Out:
#      Div        Date        HomeTeam     AwayTeam  FTHomeGoals  FTAwayGoals  \
# 0     E0    13/08/16         Burnley      Swansea            0            1
# 1     E0    13/08/16  Crystal Palace    West Brom            0            1
# 2     E0    13/08/16         Everton    Tottenham            1            1
# 3     E0    13/08/16            Hull    Leicester            2            1
# 4     E0    13/08/16        Man City   Sunderland            2            1
# ...   ..         ...             ...          ...          ...          ...
# 2655  E0  28/05/2023         Everton  Bournemouth            1            0
# 2656  E0  28/05/2023           Leeds    Tottenham            1            4
# 2657  E0  28/05/2023       Leicester     West Ham            2            1
# 2658  E0  28/05/2023      Man United       Fulham            2            1
# 2659  E0  28/05/2023     Southampton    Liverpool            4            4
#
#      FTResult  HTHomeGoals  HTAwayGoals HTResult  ... HomeFouls  AwayFouls  \
# 0           A            0            0        D  ...        10         14
# 1           A            0            0        D  ...        12         15
# 2           D            1            0        H  ...        10         14
# 3           H            1            0        H  ...         8         17
# 4           H            1            0        H  ...        11         14
# ...       ...          ...          ...      ...  ...       ...        ...
# 2655        H            0            0        D  ...        11         12
# 2656        A            0            1        A  ...         7          5
# 2657        H            1            0        H  ...         8         10
# 2658        H            1            1        D  ...        14         10
# 2659        D            2            2        D  ...         4         10
#
#       HomeCorners  AwayCorners  HomeYellow  AwayYellow  HomeRed  AwayRed  \
# 0               7            4           3           2        0        0
# 1               3            6           2           2        0        0
# 2               5            6           0           0        0        0
# 3               5            3           2           2        0        0
# 4               9            6           1           2        0        0
# ...           ...          ...         ...         ...      ...      ...
# 2655            9            3           1           3        0        0
# 2656           12            3           3           0        0        0
# 2657            3            5           1           1        0        0
# 2658            5            4           1           2        0        0
# 2659            2            9           0           2        0        0
#
#       B365H   AvgCAHA
# 0      2.40  1.947717
# 1      2.00  1.947717
# 2      3.20  1.947717
# 3      4.50  1.947717
# 4      1.25  1.947717
# ...     ...       ...
# 2655   1.50  1.830000
# 2656   2.75  2.060000
# 2657   1.91  2.040000
# 2658   1.50  1.890000
# 2659   6.50  1.980000
#
# [2660 rows x 25 columns]

# %%
import matplotlib.pyplot as plt
df.duplicated().any()
# Out:
# False

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
# Impute missing values for categorical features with mode
for col in categorical_cols:
    df[col] = le.fit_transform(df[col])

# %%
# plt.boxplot(df['FTHomeGoals'])
plt.boxplot(df['FTAwayGoals'])
# plt.boxplot(df['HTHomeGoals'])
# plt.boxplot(df['HTAwayGoals'])
plt.show()

# %%
# Outlier detection and handling
from scipy.stats import skew

numerical = df.select_dtypes(include=['int64','float64'])

skewness = numerical.apply(lambda x: skew(x.dropna()))

zScore = np.abs((numerical - numerical.mean()) / numerical.std())
# cleanedData = df[(zScore < 3).all(axis=1)]
# print('Shape :',df.shape)
# print('Shape :',cleanedData.shape)

zScore
# Out:
#       FTHomeGoals  FTAwayGoals  HTHomeGoals  HTAwayGoals  HomeShots  \
# 0        1.153289     0.197124     0.802013     0.723778   0.645654
# 1        1.153289     0.197124     0.802013     0.723778   0.058431
# 2        0.399728     0.197124     0.368231     0.723778   0.293611
# 3        0.353834     0.197124     0.368231     0.723778   0.058431
# 4        0.353834     0.197124     0.368231     0.723778   0.410474
# ...           ...          ...          ...          ...        ...
# 2655     0.399728     1.021572     0.802013     0.723778   0.117590
# 2656     0.399728     2.276221     0.802013     0.572686   0.938538
# 2657     0.353834     0.197124     0.368231     0.723778   0.117590
# 2658     0.353834     0.197124     0.368231     0.572686   1.290580
# 2659     1.860957     2.276221     1.538474     1.869150   0.234452
#
#       AwayShots  HomeShotsTarget       AST  HomeFouls  AwayFouls  HomeCorners  \
# 0      1.134502         0.646091  2.131735   0.158517   0.918243     0.434514
# 1      0.334402         0.266289  0.402151   0.426302   1.198542     0.873700
# 2      0.334402         0.493313  0.020163   0.158517   0.918243     0.219593
# 3      1.334527         0.113512  0.442477   0.743335   1.759141     0.219593
# 4      0.865747         0.266289  0.402151   0.133893   0.918243     1.088621
# ...         ...              ...       ...        ...        ...          ...
# 2655   0.865747         0.493313  0.824466   0.133893   0.357645     1.088621
# 2656   0.065647         1.025892  1.287106   1.035744   1.604449     2.069782
# 2657   0.934477         0.266289  0.402151   0.743335   0.202953     0.873700
# 2658   0.265672         1.252916  0.402151   1.011120   0.202953     0.219593
# 2659   3.734825         2.012519  1.709421   1.912971   0.202953     1.200754
#
#       AwayCorners  HomeYellow  AwayYellow   HomeRed   AwayRed     B365H  \
# 0        0.243406    1.149993    0.225947  0.221731  0.242155  0.266214
# 1        0.483261    0.338161    0.225947  0.221731  0.242155  0.432223
# 2        0.483261    1.285501    1.364049  0.221731  0.242155  0.065805
# 3        0.606740    0.338161    0.225947  0.221731  0.242155  0.605334
# 4        0.483261    0.473670    0.225947  0.221731  0.242155  0.743490
# ...           ...         ...         ...       ...       ...       ...
# 2655     0.606740    0.473670    1.020944  0.221731  0.242155  0.639734
# 2656     0.606740    1.149993    1.364049  0.221731  0.242155  0.120956
# 2657     0.119927    0.473670    0.569051  0.221731  0.242155  0.469575
# 2658     0.243406    0.473670    0.225947  0.221731  0.242155  0.639734
# 2659     1.573263    1.285501    0.225947  0.221731  0.242155  1.435380
#
#        AvgCAHA
# 0     0.000000
# 1     0.000000
# 2     0.000000
# 3     0.000000
# 4     0.000000
# ...        ...
# 2655  1.638236
# 2656  1.562610
# 2657  1.284275
# 2658  0.803233
# 2659  0.449272
#
# [2660 rows x 18 columns]

# %%
fig, ax = plt.subplots()
df.plot.bar(x='HTResult',y=['HTHomeGoals','HTAwayGoals'],ax=ax)
# Out:
# <AxesSubplot:xlabel='HTResult'>

# %%
df.plot.bar(x='FTResult' , y=['HomeShotsTarget','AST'])
# Out:
# <AxesSubplot:xlabel='FTResult'>

# %%
df.plot.bar(x='HomeShots' , y=['HomeShotsTarget','FTHomeGoals'])
# Out:
# <AxesSubplot:xlabel='HomeShots'>

# %%
df.plot.bar(x='AwayShots' , y=['AST','FTAwayGoals'])
# Out:
# <AxesSubplot:xlabel='AwayShots'>

# %%
df.plot.bar(x='HomeShotsTarget' , y=['HTHomeGoals','FTHomeGoals'])
# Out:
# <AxesSubplot:xlabel='HomeShotsTarget'>

# %%
df.plot.bar(x='AST' , y=['HTAwayGoals','FTAwayGoals'])
# Out:
# <AxesSubplot:xlabel='AST'>

# %%
custom_df = df[['HomeShots', 'HomeShotsTarget']]
custom_correlation_matrix = custom_df.corr()
print(custom_correlation_matrix)
# Out:
#                  HomeShots  HomeShotsTarget
# HomeShots         1.000000         0.689326
# HomeShotsTarget   0.689326         1.000000

# %%
zScore
# Out:
#       FTHomeGoals  FTAwayGoals  HTHomeGoals  HTAwayGoals  HomeShots  \
# 0        1.153289     0.197124     0.802013     0.723778   0.645654
# 1        1.153289     0.197124     0.802013     0.723778   0.058431
# 2        0.399728     0.197124     0.368231     0.723778   0.293611
# 3        0.353834     0.197124     0.368231     0.723778   0.058431
# 4        0.353834     0.197124     0.368231     0.723778   0.410474
# ...           ...          ...          ...          ...        ...
# 2655     0.399728     1.021572     0.802013     0.723778   0.117590
# 2656     0.399728     2.276221     0.802013     0.572686   0.938538
# 2657     0.353834     0.197124     0.368231     0.723778   0.117590
# 2658     0.353834     0.197124     0.368231     0.572686   1.290580
# 2659     1.860957     2.276221     1.538474     1.869150   0.234452
#
#       AwayShots  HomeShotsTarget       AST  HomeFouls  AwayFouls  HomeCorners  \
# 0      1.134502         0.646091  2.131735   0.158517   0.918243     0.434514
# 1      0.334402         0.266289  0.402151   0.426302   1.198542     0.873700
# 2      0.334402         0.493313  0.020163   0.158517   0.918243     0.219593
# 3      1.334527         0.113512  0.442477   0.743335   1.759141     0.219593
# 4      0.865747         0.266289  0.402151   0.133893   0.918243     1.088621
# ...         ...              ...       ...        ...        ...          ...
# 2655   0.865747         0.493313  0.824466   0.133893   0.357645     1.088621
# 2656   0.065647         1.025892  1.287106   1.035744   1.604449     2.069782
# 2657   0.934477         0.266289  0.402151   0.743335   0.202953     0.873700
# 2658   0.265672         1.252916  0.402151   1.011120   0.202953     0.219593
# 2659   3.734825         2.012519  1.709421   1.912971   0.202953     1.200754
#
#       AwayCorners  HomeYellow  AwayYellow   HomeRed   AwayRed     B365H  \
# 0        0.243406    1.149993    0.225947  0.221731  0.242155  0.266214
# 1        0.483261    0.338161    0.225947  0.221731  0.242155  0.432223
# 2        0.483261    1.285501    1.364049  0.221731  0.242155  0.065805
# 3        0.606740    0.338161    0.225947  0.221731  0.242155  0.605334
# 4        0.483261    0.473670    0.225947  0.221731  0.242155  0.743490
# ...           ...         ...         ...       ...       ...       ...
# 2655     0.606740    0.473670    1.020944  0.221731  0.242155  0.639734
# 2656     0.606740    1.149993    1.364049  0.221731  0.242155  0.120956
# 2657     0.119927    0.473670    0.569051  0.221731  0.242155  0.469575
# 2658     0.243406    0.473670    0.225947  0.221731  0.242155  0.639734
# 2659     1.573263    1.285501    0.225947  0.221731  0.242155  1.435380
#
#        AvgCAHA
# 0     0.000000
# 1     0.000000
# 2     0.000000
# 3     0.000000
# 4     0.000000
# ...        ...
# 2655  1.638236
# 2656  1.562610
# 2657  1.284275
# 2658  0.803233
# 2659  0.449272
#
# [2660 rows x 18 columns]

# %%
custom_df = df[['AwayShots', 'AST']]
custom_correlation_matrix = custom_df.corr()
print(custom_correlation_matrix)
# Out:
#            AwayShots       AST
# AwayShots   1.000000  0.689564
# AST         0.689564  1.000000

# %%
custom_df = df[['FTHomeGoals', 'HTHomeGoals']]
custom_correlation_matrix = custom_df.corr()
print(custom_correlation_matrix)
# Out:
#              FTHomeGoals  HTHomeGoals
# FTHomeGoals      1.00000      0.70143
# HTHomeGoals      0.70143      1.00000

# %%
custom_df = df[['FTAwayGoals', 'HTAwayGoals']]
custom_correlation_matrix = custom_df.corr()
print(custom_correlation_matrix)
# Out:
#              FTAwayGoals  HTAwayGoals
# FTAwayGoals      1.00000      0.70706
# HTAwayGoals      0.70706      1.00000

# %%
correlation_matrix = df.corr()
print(correlation_matrix)
# Out:
#                  Div      Date  HomeTeam  AwayTeam  FTHomeGoals  FTAwayGoals  \
# Div              NaN       NaN       NaN       NaN          NaN          NaN
# Date             NaN  1.000000 -0.009167  0.024099    -0.036621    -0.002441
# HomeTeam         NaN -0.009167  1.000000 -0.041264    -0.033958     0.032646
# AwayTeam         NaN  0.024099 -0.041264  1.000000     0.009744    -0.028115
# FTHomeGoals      NaN -0.036621 -0.033958  0.009744     1.000000    -0.145883
# FTAwayGoals      NaN -0.002441  0.032646 -0.028115    -0.145883     1.000000
# FTResult         NaN -0.038860 -0.034146  0.031111     0.644278    -0.655621
# HTHomeGoals      NaN -0.035697 -0.013322 -0.014109     0.701430    -0.087400
# HTAwayGoals      NaN -0.014075  0.018498 -0.023506    -0.095793     0.707060
# HTResult         NaN -0.032688 -0.022836  0.010925     0.484119    -0.484505
# Referee          NaN  0.024296  0.013691  0.026238     0.019728    -0.054194
# HomeShots        NaN -0.013072 -0.046963 -0.002092     0.343424    -0.182444
# AwayShots        NaN  0.004189  0.024962 -0.021226    -0.196142     0.361653
# HomeShotsTarget  NaN -0.053205 -0.041656  0.006303     0.608865    -0.180165
# AST              NaN  0.001109  0.025561 -0.018895    -0.162487     0.602646
# HomeFouls        NaN -0.009545  0.046482 -0.067701    -0.074243    -0.011041
# AwayFouls        NaN -0.017676 -0.111014  0.034999    -0.043186    -0.021250
# HomeCorners      NaN  0.000191 -0.052874 -0.016906     0.076524    -0.124530
# AwayCorners      NaN -0.014365 -0.010262 -0.000100    -0.092390     0.063529
# HomeYellow       NaN -0.020901  0.017373 -0.015417    -0.161341     0.064168
# AwayYellow       NaN -0.005724 -0.010705 -0.006963    -0.013964    -0.035802
# HomeRed          NaN  0.000935 -0.006176 -0.049881    -0.062470     0.121408
# AwayRed          NaN -0.024825 -0.021671  0.014496     0.059805    -0.065792
# B365H            NaN  0.029973  0.019568 -0.023995    -0.285759     0.332325
# AvgCAHA          NaN -0.027128  0.027196  0.026331    -0.024261     0.064419
#
#                  FTResult  HTHomeGoals  HTAwayGoals  HTResult  ...  HomeFouls  \
# Div                   NaN          NaN          NaN       NaN  ...        NaN
# Date            -0.038860    -0.035697    -0.014075 -0.032688  ...  -0.009545
# HomeTeam        -0.034146    -0.013322     0.018498 -0.022836  ...   0.046482
# AwayTeam         0.031111    -0.014109    -0.023506  0.010925  ...  -0.067701
# FTHomeGoals      0.644278     0.701430    -0.095793  0.484119  ...  -0.074243
# FTAwayGoals     -0.655621    -0.087400     0.707060 -0.484505  ...  -0.011041
# FTResult         1.000000     0.430714    -0.454034  0.609241  ...  -0.034386
# HTHomeGoals      0.430714     1.000000    -0.079726  0.667769  ...  -0.054727
# HTAwayGoals     -0.454034    -0.079726     1.000000 -0.654302  ...   0.006127
# HTResult         0.609241     0.667769    -0.654302  1.000000  ...  -0.037026
# Referee          0.038763    -0.010779    -0.052615  0.021579  ...   0.024980
# HomeShots        0.283572     0.160371    -0.087887  0.133625  ...  -0.087055
# AwayShots       -0.296772    -0.062793     0.219205 -0.160719  ...   0.038334
# HomeShotsTarget  0.442190     0.405153    -0.113734  0.324342  ...  -0.048450
# AST             -0.434682    -0.079914     0.432391 -0.311946  ...   0.032827
# HomeFouls       -0.034386    -0.054727     0.006127 -0.037026  ...   1.000000
# AwayFouls        0.011778    -0.018006     0.003932 -0.022188  ...   0.133004
# HomeCorners      0.108050    -0.009646    -0.055824  0.018184  ...  -0.059243
# AwayCorners     -0.063473     0.007792    -0.015561  0.034215  ...  -0.004077
# HomeYellow      -0.106901    -0.110634     0.066327 -0.103085  ...   0.372878
# AwayYellow       0.017555    -0.004508    -0.027501  0.001534  ...   0.105158
# HomeRed         -0.111837    -0.013241     0.075524 -0.046297  ...   0.036476
# AwayRed          0.076388     0.014216    -0.029445  0.011529  ...   0.022838
# B365H           -0.378633    -0.190600     0.256935 -0.285658  ...  -0.051296
# AvgCAHA         -0.061976    -0.007389     0.050837 -0.027955  ...  -0.006186
#
#                  AwayFouls  HomeCorners  AwayCorners  HomeYellow  AwayYellow  \
# Div                    NaN          NaN          NaN         NaN         NaN
# Date             -0.017676     0.000191    -0.014365   -0.020901   -0.005724
# HomeTeam         -0.111014    -0.052874    -0.010262    0.017373   -0.010705
# AwayTeam          0.034999    -0.016906    -0.000100   -0.015417   -0.006963
# FTHomeGoals      -0.043186     0.076524    -0.092390   -0.161341   -0.013964
# FTAwayGoals      -0.021250    -0.124530     0.063529    0.064168   -0.035802
# FTResult          0.011778     0.108050    -0.063473   -0.106901    0.017555
# HTHomeGoals      -0.018006    -0.009646     0.007792   -0.110634   -0.004508
# HTAwayGoals       0.003932    -0.055824    -0.015561    0.066327   -0.027501
# HTResult         -0.022188     0.018184     0.034215   -0.103085    0.001534
# Referee           0.034227     0.000876     0.002916    0.011554    0.035137
# HomeShots        -0.031426     0.564661    -0.373780   -0.126498    0.078522
# AwayShots        -0.048014    -0.365232     0.543583    0.122180   -0.094543
# HomeShotsTarget  -0.032365     0.337787    -0.236465   -0.140907    0.038728
# AST              -0.031655    -0.229475     0.310695    0.075571   -0.088776
# HomeFouls         0.133004    -0.059243    -0.004077    0.372878    0.105158
# AwayFouls         1.000000    -0.026105    -0.051295    0.091763    0.352265
# HomeCorners      -0.026105     1.000000    -0.316871   -0.069205    0.064694
# AwayCorners      -0.051295    -0.316871     1.000000    0.063372   -0.060783
# HomeYellow        0.091763    -0.069205     0.063372    1.000000    0.181095
# AwayYellow        0.352265     0.064694    -0.060783    0.181095    1.000000
# HomeRed           0.020868    -0.069823     0.077122   -0.009653    0.025115
# AwayRed           0.056411     0.057723    -0.070889    0.037511    0.012490
# B365H            -0.108921    -0.354637     0.310749    0.059771   -0.096482
# AvgCAHA           0.009468    -0.050924     0.034832    0.021436   -0.012554
#
#                   HomeRed   AwayRed     B365H   AvgCAHA
# Div                   NaN       NaN       NaN       NaN
# Date             0.000935 -0.024825  0.029973 -0.027128
# HomeTeam        -0.006176 -0.021671  0.019568  0.027196
# AwayTeam        -0.049881  0.014496 -0.023995  0.026331
# FTHomeGoals     -0.062470  0.059805 -0.285759 -0.024261
# FTAwayGoals      0.121408 -0.065792  0.332325  0.064419
# FTResult        -0.111837  0.076388 -0.378633 -0.061976
# HTHomeGoals     -0.013241  0.014216 -0.190600 -0.007389
# HTAwayGoals      0.075524 -0.029445  0.256935  0.050837
# HTResult        -0.046297  0.011529 -0.285658 -0.027955
# Referee         -0.036779  0.005074 -0.035823 -0.038439
# HomeShots       -0.089894  0.080729 -0.448128 -0.051994
# AwayShots        0.150992 -0.098746  0.450788  0.066541
# HomeShotsTarget -0.076042  0.070829 -0.357872 -0.041126
# AST              0.148481 -0.063098  0.376945  0.066863
# HomeFouls        0.036476  0.022838 -0.051296 -0.006186
# AwayFouls        0.020868  0.056411 -0.108921  0.009468
# HomeCorners     -0.069823  0.057723 -0.354637 -0.050924
# AwayCorners      0.077122 -0.070889  0.310749  0.034832
# HomeYellow      -0.009653  0.037511  0.059771  0.021436
# AwayYellow       0.025115  0.012490 -0.096482 -0.012554
# HomeRed          1.000000  0.001319 -0.006192  0.011013
# AwayRed          0.001319  1.000000 -0.025811  0.012218
# B365H           -0.006192 -0.025811  1.000000  0.077050
# AvgCAHA          0.011013  0.012218  0.077050  1.000000
#
# [25 rows x 25 columns]

# %%
correlation_matrix = zScore.corr()
print(correlation_matrix)
# Out:
#                  FTHomeGoals  FTAwayGoals  HTHomeGoals  HTAwayGoals  \
# FTHomeGoals         1.000000     0.015006     0.523425    -0.011581
# FTAwayGoals         0.015006     1.000000    -0.006306     0.511882
# HTHomeGoals         0.523425    -0.006306     1.000000    -0.017690
# HTAwayGoals        -0.011581     0.511882    -0.017690     1.000000
# HomeShots           0.091753     0.053810     0.022694     0.067993
# AwayShots           0.054012     0.130134     0.007715     0.043394
# HomeShotsTarget     0.344526     0.029337     0.165738     0.039217
# AST                 0.042036     0.338236     0.009566     0.184942
# HomeFouls           0.036126     0.004572     0.031227    -0.003469
# AwayFouls           0.028469     0.006421    -0.011105     0.016411
# HomeCorners        -0.021377     0.006223    -0.016864     0.003192
# AwayCorners         0.025088     0.009889     0.027599    -0.018130
# HomeYellow         -0.028339     0.002562    -0.025820     0.019323
# AwayYellow         -0.033705     0.024163    -0.040018     0.012864
# HomeRed            -0.021296     0.074571    -0.009301     0.059183
# AwayRed             0.028099    -0.047525     0.022320    -0.037005
# B365H               0.060163     0.131856    -0.007670     0.134835
# AvgCAHA            -0.044498    -0.008249    -0.043117     0.025346
#
#                  HomeShots  AwayShots  HomeShotsTarget       AST  HomeFouls  \
# FTHomeGoals       0.091753   0.054012         0.344526  0.042036   0.036126
# FTAwayGoals       0.053810   0.130134         0.029337  0.338236   0.004572
# HTHomeGoals       0.022694   0.007715         0.165738  0.009566   0.031227
# HTAwayGoals       0.067993   0.043394         0.039217  0.184942  -0.003469
# HomeShots         1.000000   0.165529         0.441006  0.061509   0.007967
# AwayShots         0.165529   1.000000         0.068702  0.431365   0.022242
# HomeShotsTarget   0.441006   0.068702         1.000000  0.033053   0.024228
# AST               0.061509   0.431365         0.033053  1.000000   0.005762
# HomeFouls         0.007967   0.022242         0.024228  0.005762   1.000000
# AwayFouls         0.003500   0.031960         0.004084  0.014007   0.023702
# HomeCorners       0.288905   0.110868         0.065795  0.040897  -0.004057
# AwayCorners       0.092655   0.275344         0.025500  0.041302   0.001259
# HomeYellow       -0.032465   0.012423        -0.024428  0.009431   0.131814
# AwayYellow        0.021424  -0.003147        -0.028073  0.003182   0.000210
# HomeRed           0.018260   0.062045         0.001097  0.087704  -0.015596
# AwayRed           0.035775  -0.004638         0.061349 -0.007748  -0.031656
# B365H             0.175824   0.211775         0.110716  0.136544   0.019142
# AvgCAHA          -0.038285   0.020421        -0.052189 -0.004927   0.000943
#
#                  AwayFouls  HomeCorners  AwayCorners  HomeYellow  AwayYellow  \
# FTHomeGoals       0.028469    -0.021377     0.025088   -0.028339   -0.033705
# FTAwayGoals       0.006421     0.006223     0.009889    0.002562    0.024163
# HTHomeGoals      -0.011105    -0.016864     0.027599   -0.025820   -0.040018
# HTAwayGoals       0.016411     0.003192    -0.018130    0.019323    0.012864
# HomeShots         0.003500     0.288905     0.092655   -0.032465    0.021424
# AwayShots         0.031960     0.110868     0.275344    0.012423   -0.003147
# HomeShotsTarget   0.004084     0.065795     0.025500   -0.024428   -0.028073
# AST               0.014007     0.040897     0.041302    0.009431    0.003182
# HomeFouls         0.023702    -0.004057     0.001259    0.131814    0.000210
# AwayFouls         1.000000     0.003334     0.034915    0.006875    0.101839
# HomeCorners       0.003334     1.000000     0.110092   -0.016840    0.015223
# AwayCorners       0.034915     0.110092     1.000000    0.013877   -0.005684
# HomeYellow        0.006875    -0.016840     0.013877    1.000000    0.011601
# AwayYellow        0.101839     0.015223    -0.005684    0.011601    1.000000
# HomeRed          -0.023817     0.008146     0.028138   -0.028071    0.027084
# AwayRed           0.031873     0.034349    -0.018529   -0.045173   -0.003763
# B365H             0.034232     0.092104     0.151702    0.002775    0.010318
# AvgCAHA           0.011962    -0.021871    -0.027899   -0.011965   -0.033325
#
#                   HomeRed   AwayRed     B365H   AvgCAHA
# FTHomeGoals     -0.021296  0.028099  0.060163 -0.044498
# FTAwayGoals      0.074571 -0.047525  0.131856 -0.008249
# HTHomeGoals     -0.009301  0.022320 -0.007670 -0.043117
# HTAwayGoals      0.059183 -0.037005  0.134835  0.025346
# HomeShots        0.018260  0.035775  0.175824 -0.038285
# AwayShots        0.062045 -0.004638  0.211775  0.020421
# HomeShotsTarget  0.001097  0.061349  0.110716 -0.052189
# AST              0.087704 -0.007748  0.136544 -0.004927
# HomeFouls       -0.015596 -0.031656  0.019142  0.000943
# AwayFouls       -0.023817  0.031873  0.034232  0.011962
# HomeCorners      0.008146  0.034349  0.092104 -0.021871
# AwayCorners      0.028138 -0.018529  0.151702 -0.027899
# HomeYellow      -0.028071 -0.045173  0.002775 -0.011965
# AwayYellow       0.027084 -0.003763  0.010318 -0.033325
# HomeRed          1.000000  0.000897 -0.033567 -0.009625
# AwayRed          0.000897  1.000000 -0.048323 -0.010564
# B365H           -0.033567 -0.048323  1.000000 -0.073660
# AvgCAHA         -0.009625 -0.010564 -0.073660  1.000000
